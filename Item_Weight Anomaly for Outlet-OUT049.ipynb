# %%
#Import Libraries :-

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Analysis dataset :-

# %%
df=pd.read_csv('C:\\Users\\arpit\\Downloads\\train_v9rqX0R.csv')
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
#Actual dataset :-

# %%
df1=pd.read_csv('C:\\Users\\arpit\\Downloads\\test_AbJTz2l.csv')
df1
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
#Renaming the column of the actual dataset :-

# %%
df1.rename({'Item_Weight':'Original_Weight','Item_Fat_Content':'Original_Fat','Item_Visibility':'Visibility','Item_MRP':'Original_MRP'},axis=1,inplace=True)
df1
# Out:
#      Item_Identifier  Original_Weight Original_Fat  Visibility  \
# 0              FDW58           20.750      Low Fat    0.007565
# 1              FDW14            8.300          reg    0.038428
# 2              NCN55           14.600      Low Fat    0.099575
# 3              FDQ58            7.315      Low Fat    0.015388
# 4              FDY38              NaN      Regular    0.118599
# ...              ...              ...          ...         ...
# 5676           FDB58           10.500      Regular    0.013496
# 5677           FDD47            7.600      Regular    0.142991
# 5678           NCO17           10.000      Low Fat    0.073529
# 5679           FDJ26           15.300      Regular    0.000000
# 5680           FDU37            9.500      Regular    0.104720
#
#                Item_Type  Original_MRP Outlet_Identifier  \
# 0            Snack Foods      107.8622            OUT049
# 1                  Dairy       87.3198            OUT017
# ...

# %%
#Assigning to a new variable :-

# %%
df2=df1
df2
# Out:
#      Item_Identifier  Original_Weight Original_Fat  Visibility  \
# 0              FDW58           20.750      Low Fat    0.007565
# 1              FDW14            8.300          reg    0.038428
# 2              NCN55           14.600      Low Fat    0.099575
# 3              FDQ58            7.315      Low Fat    0.015388
# 4              FDY38              NaN      Regular    0.118599
# ...              ...              ...          ...         ...
# 5676           FDB58           10.500      Regular    0.013496
# 5677           FDD47            7.600      Regular    0.142991
# 5678           NCO17           10.000      Low Fat    0.073529
# 5679           FDJ26           15.300      Regular    0.000000
# 5680           FDU37            9.500      Regular    0.104720
#
#                Item_Type  Original_MRP Outlet_Identifier  \
# 0            Snack Foods      107.8622            OUT049
# 1                  Dairy       87.3198            OUT017
# ...

# %%
#Merged dataset :-

# %%
df3=pd.merge(df,df2,on='Outlet_Identifier',how='inner')
df3
# Out:
#         Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                   FDA15          9.3          Low Fat         0.016047
# 1                   FDA15          9.3          Low Fat         0.016047
# 2                   FDA15          9.3          Low Fat         0.016047
# 3                   FDA15          9.3          Low Fat         0.016047
# 4                   FDA15          9.3          Low Fat         0.016047
# ...                   ...          ...              ...              ...
# 5003110             FDU44          NaN          Regular         0.102296
# 5003111             FDU44          NaN          Regular         0.102296
# 5003112             FDU44          NaN          Regular         0.102296
# 5003113             FDU44          NaN          Regular         0.102296
# 5003114             FDU44          NaN          Regular         0.102296
#
#                    Item_Type_x  Item_MRP Outlet_Identifier  \
# ...

# %%
#Let's see how the overall sales gets affected due to mismatched of Item_Weight in the merged dataset :-

# %%
df3['Mismatched_Weight']=df3['Item_Weight']>df3['Original_Weight']
df3
# Out:
#         Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0                   FDA15          9.3          Low Fat         0.016047
# 1                   FDA15          9.3          Low Fat         0.016047
# 2                   FDA15          9.3          Low Fat         0.016047
# 3                   FDA15          9.3          Low Fat         0.016047
# 4                   FDA15          9.3          Low Fat         0.016047
# ...                   ...          ...              ...              ...
# 5003110             FDU44          NaN          Regular         0.102296
# 5003111             FDU44          NaN          Regular         0.102296
# 5003112             FDU44          NaN          Regular         0.102296
# 5003113             FDU44          NaN          Regular         0.102296
# 5003114             FDU44          NaN          Regular         0.102296
#
#                    Item_Type_x  Item_MRP Outlet_Identifier  \
# ...

# %%
#Let's see how many rows contain more weight on the basis of Mismatched_Weight :-

# %%
df3['Mismatched_Weight'].value_counts()
# Out:
# False    2855142
# True     2147973
# Name: Mismatched_Weight, dtype: int64

# %%
#Subset :-

# %%
df4=df3[df3['Mismatched_Weight']==True]
df4
# Out:
#         Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1                   FDA15          9.3          Low Fat         0.016047
# 2                   FDA15          9.3          Low Fat         0.016047
# 3                   FDA15          9.3          Low Fat         0.016047
# 5                   FDA15          9.3          Low Fat         0.016047
# 7                   FDA15          9.3          Low Fat         0.016047
# ...                   ...          ...              ...              ...
# 4817248             NCJ29         10.6          Low Fat         0.035186
# 4817249             NCJ29         10.6          Low Fat         0.035186
# 4817251             NCJ29         10.6          Low Fat         0.035186
# 4817254             NCJ29         10.6          Low Fat         0.035186
# 4817258             NCJ29         10.6          Low Fat         0.035186
#
#                 Item_Type_x  Item_MRP Outlet_Identifier  \
# ...

# %%
#Let's see how the overall sales affected by the mismatched of Item_Weight for a particular product on the basis of a particular Outlet with Outlet_Identifier as OUT049.

# %% [markdown]
# #### Dairy :-

# %%
#Subset :-

# %%
df5=df4[(df4['Outlet_Identifier']=='OUT049')&(df4['Item_Type_x']=='Dairy')&(df4['Item_Type_y']=='Dairy')]
df5
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# 564141             FDV50         14.3          Low Fat         0.122762
# 564152             FDV50         14.3          Low Fat         0.122762
# 564160             FDV50         14.3          Low Fat         0.122762
# 564163             FDV50         14.3          Low Fat         0.122762
# 564174             FDV50         14.3          Low Fat         0.122762
#
#        Item_Type_x  Item_MRP Outlet_Identifier  Outlet_Establishment_Year_x  \
# ...

# %%
#Calculate total_Item_Sold :-

# %%
df5['Item_Sold']=df5['Item_Outlet_Sales']/df5['Item_MRP']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# ...

# %%
#Calculate Original_Sales:-

# %%
df5['Original_Sales']=df5['Item_Sold']*df5['Original_MRP']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# ...

# %%
#Now compare Item_Outlet_Sales and Original_Sales :-

# %%
df5['Greater_Sales']=df5['Item_Outlet_Sales']>df5['Original_Sales']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# ...

# %%
#Now see the value_counts of Greater_Sales :-

# %%
df5['Greater_Sales'].value_counts()
# Out:
# True     1334
# False     883
# Name: Greater_Sales, dtype: int64

# %%
#Subset :-

# %%
df6=df5[df5['Greater_Sales']==True]
df6
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# 564052             FDV50         14.3          Low Fat         0.122762
# 564054             FDV50         14.3          Low Fat         0.122762
# 564129             FDV50         14.3          Low Fat         0.122762
# 564141             FDV50         14.3          Low Fat         0.122762
# 564152             FDV50         14.3          Low Fat         0.122762
#
#        Item_Type_x  Item_MRP Outlet_Identifier  Outlet_Establishment_Year_x  \
# ...

# %%
#Calculate Extra_Money :-

# %%
df6['Extra_Money']=df6['Item_Outlet_Sales']-df6['Original_Sales']
df6
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# ...

# %%
#Rename the columns:-

# %%
df6.rename({'Item_Identifier_y':'Item_ID'},axis=1,inplace=True)
df6
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# 564052             FDV50         14.3          Low Fat         0.122762
# 564054             FDV50         14.3          Low Fat         0.122762
# ...

# %%
#Assign to a new variable :-

# %%
df7=df6
df7
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 82                 FDA15          9.3          Low Fat         0.016047
# 139                FDA15          9.3          Low Fat         0.016047
# 153                FDA15          9.3          Low Fat         0.016047
# 202                FDA15          9.3          Low Fat         0.016047
# 209                FDA15          9.3          Low Fat         0.016047
# ...                  ...          ...              ...              ...
# 564052             FDV50         14.3          Low Fat         0.122762
# 564054             FDV50         14.3          Low Fat         0.122762
# 564129             FDV50         14.3          Low Fat         0.122762
# 564141             FDV50         14.3          Low Fat         0.122762
# 564152             FDV50         14.3          Low Fat         0.122762
#
#        Item_Type_x  Item_MRP Outlet_Identifier  Outlet_Establishment_Year_x  \
# ...

# %%
#Groupby :-

# %%
df8=df7.groupby(['Outlet_Identifier','Item_ID','Mismatched_Weight']).agg({'Mismatched_Weight':'count','Item_Outlet_Sales':'sum','Original_Sales':'sum','Item_Sold':'sum','Extra_Money':'sum'})
df8
# Out:
#                                              Mismatched_Weight  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            DRE15   True                              38
#                   DRF15   True                               6
#                   DRG03   True                              13
#                   DRH15   True                              62
#                   DRI39   True                              34
#                   DRI51   True                               8
#                   DRJ39   True                               2
#                   FDA26   True                              18
#                   FDA51   True                              44
#                   FDB04   True                              43
#                   FDB28   True                              20
#                   FDB51   True                              62
#                   FDC39   True                              20
# ...

# %%
#Rename the columns :-

# %%
df8.rename({'Mismatched_Weight':'Weight'},axis=1,inplace=True)
df8
# Out:
#                                              Weight  Item_Outlet_Sales  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            DRE15   True                   38         92445.6642
#                   DRF15   True                    6         19457.3392
#                   DRG03   True                   13         39135.0582
#                   DRH15   True                   62        156077.5018
#                   DRI39   True                   34         75801.9958
#                   DRI51   True                    8         26371.0064
#                   DRJ39   True                    2          6207.9192
#                   FDA26   True                   18         64597.2476
#                   FDA51   True                   44        136194.7164
#                   FDB04   True                   43        110669.2760
#                   FDB28   True                   20         67635.2930
#                   FDB51   True                   62        159786.6736
# ...

# %%
#Sort the columns :-

# %%
df9=df8.sort_values(by='Original_Sales',ascending=False)
df9
# Out:
#                                              Weight  Item_Outlet_Sales  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            FDW02   True                   44        136782.6178
#                   FDA51   True                   44        136194.7164
#                   FDE39   True                   42        131298.4232
#                   FDZ14   True                   41        130225.8194
#                   FDY50   True                   58        157608.8418
#                   FDY27   True                   29         97839.9758
#                   FDP26   True                   46        139506.4056
#                   FDS14   True                   32        106108.5460
#                   FDZ02   True                   50        145197.6640
#                   FDW14   True                   54        149191.1324
#                   FDT14   True                   36        109765.1196
#                   FDE52   True                   45        126260.3146
# ...

# %%
#Write to an excel file :-

# %%
df9.to_excel('Item886.xlsx')

# %%
#Read from the file :-

# %%
df=pd.read_excel('C:\\Users\\arpit\\Item886.xlsx')
df
# Out:
#    Outlet_Identifier Item_ID  Mismatched_Weight  Weight  Item_Outlet_Sales  \
# 0             OUT049   FDW02               True      44        136782.6178
# 1             OUT049   FDA51               True      44        136194.7164
# 2             OUT049   FDE39               True      42        131298.4232
# 3             OUT049   FDZ14               True      41        130225.8194
# 4             OUT049   FDY50               True      58        157608.8418
# 5             OUT049   FDY27               True      29         97839.9758
# 6             OUT049   FDP26               True      46        139506.4056
# 7             OUT049   FDS14               True      32        106108.5460
# 8             OUT049   FDZ02               True      50        145197.6640
# 9             OUT049   FDW14               True      54        149191.1324
# 10            OUT049   FDT14               True      36        109765.1196
# ...

# %%
#Plot the graph and show how the Original_Sales gets affected on the basis of mismatched of weight for a particular Outlet :-

# %%
#Show top-10 graph :-

# %%
df1=df[['Item_ID','Original_Sales','Item_Sold']].head(10)
df1
# Out:
#   Item_ID  Original_Sales   Item_Sold
# 0   FDW02    84416.584251  677.661662
# 1   FDA51    81602.389235  706.197474
# 2   FDE39    80151.928790  665.281593
# 3   FDZ14    79474.123072  656.400820
# 4   FDY50    79155.067212  891.213270
# 5   FDY27    77394.313587  433.498046
# 6   FDP26    76875.960284  736.144006
# 7   FDS14    75803.031326  484.894858
# 8   FDZ02    75456.777062  784.597454
# 9   FDW14    72127.660745  839.476590

# %%
#Graph-1 :-

# %%
fig,ax=plt.subplots(figsize=(8,6))
df1.plot.bar(x='Item_ID',y='Original_Sales',width=0.2,color='r',label='Item_ID vs Sales & Item_Sold',ax=ax)
df1['Item_Sold'].plot(secondary_y=True,ax=ax,color='b')
ax.set_xticklabels(df1['Item_ID'],rotation=90)
plt.title('Item_ID vs Sales & Item_Sold')
plt.legend()
plt.xlabel('Item_ID')
plt.ylabel('Sales & Item_Sold')
plt.show()

# %%
#Graph-2 :-Plot top-10 data which will show how the extra_money earn by the supermarket owner due to mismatched of Weight :-

# %%
df1=df.loc[0:9,['Item_ID','Extra_Money','Weight']]
df1
# Out:
#   Item_ID   Extra_Money  Weight
# 0   FDW02  52366.033549      44
# 1   FDA51  54592.327165      44
# 2   FDE39  51146.494410      42
# 3   FDZ14  50751.696328      41
# 4   FDY50  78453.774588      58
# 5   FDY27  20445.662213      29
# 6   FDP26  62630.445316      46
# 7   FDS14  30305.514674      32
# 8   FDZ02  69740.886938      50
# 9   FDW14  77063.471655      54

# %%
fig,ax=plt.subplots(figsize=(8,6))
df1.plot.bar(x='Item_ID',y='Extra_Money',width=0.2,color='g',label='Item_ID vs Extra_Money & Weight',ax=ax)
df1['Weight'].plot(secondary_y=True,ax=ax,color='b')
ax.set_xticklabels(df1['Item_ID'],rotation=90)
plt.title('Item_ID vs Extra_Money & Weight')
plt.legend()
plt.xlabel('Item_ID')
plt.ylabel('Extra_Money & Weight')
plt.show()

# %%
#Now let's see for the other products:-

# %%
#Let's find out all the Outlet_Identifier :-

# %%
df3['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
#Let's find out all the Item_Type :-

# %%
df3['Item_Type_x'].unique()
# Out:
# array(['Dairy', 'Meat', 'Fruits and Vegetables', 'Breakfast',
#        'Health and Hygiene', 'Snack Foods', 'Hard Drinks', 'Household',
#        'Frozen Foods', 'Others', 'Baking Goods', 'Soft Drinks', 'Canned',
#        'Seafood', 'Breads', 'Starchy Foods'], dtype=object)

# %% [markdown]
# #### Meat :-

# %%
#Subset :-

# %%
df5=df4[(df4['Outlet_Identifier']=='OUT049')&(df4['Item_Type_x']=='Meat')&(df4['Item_Type_y']=='Meat')]
df5
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 666                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 744                FDN15         17.5          Low Fat         0.016760
# 782                FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# 573345             FDX15         17.2               LF         0.156542
# 573407             FDX15         17.2               LF         0.156542
# 573428             FDX15         17.2               LF         0.156542
# 573449             FDX15         17.2               LF         0.156542
# 573489             FDX15         17.2               LF         0.156542
#
#        Item_Type_x  Item_MRP Outlet_Identifier  Outlet_Establishment_Year_x  \
# ...

# %%
#Calculate the Item_Sold :-

# %%
df5['Item_Sold']=df5['Item_Outlet_Sales']/df5['Item_MRP']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 666                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 744                FDN15         17.5          Low Fat         0.016760
# 782                FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# ...

# %%
#Calculate Original_Sales :-

# %%
df5['Original_Sales']=df5['Item_Sold']*df5['Original_MRP']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 666                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 744                FDN15         17.5          Low Fat         0.016760
# 782                FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# ...

# %%
#Now compare the Item_Outlet_Sales and Original_Sales Column :-

# %%
df5['Greater_Sales']=df5['Item_Outlet_Sales']>df5['Original_Sales']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 666                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 744                FDN15         17.5          Low Fat         0.016760
# 782                FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# ...

# %%
#Now find out the count of the unique values in the Greater_Sales column :-

# %%
df5['Greater_Sales'].value_counts()
# Out:
# False    311
# True     204
# Name: Greater_Sales, dtype: int64

# %%
#Subset on the basis of Greater Column :-

# %%
df6=df5[df5['Greater_Sales']==True]
df6
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 831                FDN15         17.5          Low Fat         0.016760
# 1004               FDN15         17.5          Low Fat         0.016760
# 1061               FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# 573264             FDX15         17.2               LF         0.156542
# 573321             FDX15         17.2               LF         0.156542
# 573345             FDX15         17.2               LF         0.156542
# 573407             FDX15         17.2               LF         0.156542
# 573489             FDX15         17.2               LF         0.156542
#
#        Item_Type_x  Item_MRP Outlet_Identifier  Outlet_Establishment_Year_x  \
# ...

# %%
#Calculate Extra_Money :-

# %%
df6['Extra_Money']=df6['Item_Outlet_Sales']-df6['Original_Sales']
df6
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 831                FDN15         17.5          Low Fat         0.016760
# 1004               FDN15         17.5          Low Fat         0.016760
# 1061               FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# ...

# %%
#Rename the column :-

# %%
df6.rename({'Item_Identifier_y':'Item_ID'},axis=1,inplace=True)
df6
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 831                FDN15         17.5          Low Fat         0.016760
# 1004               FDN15         17.5          Low Fat         0.016760
# 1061               FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# 573264             FDX15         17.2               LF         0.156542
# 573321             FDX15         17.2               LF         0.156542
# ...

# %%
#Assign to a new variable :-

# %%
df7=df6
df7
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 661                FDN15         17.5          Low Fat         0.016760
# 699                FDN15         17.5          Low Fat         0.016760
# 831                FDN15         17.5          Low Fat         0.016760
# 1004               FDN15         17.5          Low Fat         0.016760
# 1061               FDN15         17.5          Low Fat         0.016760
# ...                  ...          ...              ...              ...
# 573264             FDX15         17.2               LF         0.156542
# 573321             FDX15         17.2               LF         0.156542
# 573345             FDX15         17.2               LF         0.156542
# 573407             FDX15         17.2               LF         0.156542
# 573489             FDX15         17.2               LF         0.156542
#
#        Item_Type_x  Item_MRP Outlet_Identifier  Outlet_Establishment_Year_x  \
# ...

# %%
#Groupby :-

# %%
df8=df7.groupby(['Outlet_Identifier','Item_ID','Mismatched_Weight']).agg({'Mismatched_Weight':'count','Item_Outlet_Sales':'sum','Original_Sales':'sum','Extra_Money':'sum','Item_Sold':'sum'})
df8
# Out:
#                                              Mismatched_Weight  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            FDH19   True                               1
#                   FDJ07   True                              20
#                   FDK55   True                               2
#                   FDM03   True                              11
#                   FDM15   True                              12
#                   FDN39   True                               1
#                   FDO03   True                               1
#                   FDO51   True                              36
#                   FDP27   True                               8
#                   FDP51   True                               9
#                   FDQ51   True                              10
#                   FDS03   True                              30
#                   FDS39   True                              16
# ...

# %%
#Rename the column :-

# %%
df8.rename({'Mismatched_Weight':'Weight'},axis=1,inplace=True)
df8
# Out:
#                                              Weight  Item_Outlet_Sales  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            FDH19   True                    1          4925.5884
#                   FDJ07   True                   20         54528.3542
#                   FDK55   True                    2          6448.9388
#                   FDM03   True                   11         34070.3176
#                   FDM15   True                   12         39679.6826
#                   FDN39   True                    1          4925.5884
#                   FDO03   True                    1          1896.1984
#                   FDO51   True                   36         83806.9092
#                   FDP27   True                    8         26336.3848
#                   FDP51   True                    9         28046.1592
#                   FDQ51   True                   10         22423.4782
#                   FDS03   True                   30         74929.7978
# ...

# %%
#Assign to a new variable :-

# %%
df9=df8
df9
# Out:
#                                              Weight  Item_Outlet_Sales  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            FDH19   True                    1          4925.5884
#                   FDJ07   True                   20         54528.3542
#                   FDK55   True                    2          6448.9388
#                   FDM03   True                   11         34070.3176
#                   FDM15   True                   12         39679.6826
#                   FDN39   True                    1          4925.5884
#                   FDO03   True                    1          1896.1984
#                   FDO51   True                   36         83806.9092
#                   FDP27   True                    8         26336.3848
#                   FDP51   True                    9         28046.1592
#                   FDQ51   True                   10         22423.4782
#                   FDS03   True                   30         74929.7978
# ...

# %%
#Sort the data  :-

# %%
df10=df9.sort_values(by='Original_Sales',ascending=False)
df10
# Out:
#                                              Weight  Item_Outlet_Sales  \
# Outlet_Identifier Item_ID Mismatched_Weight
# OUT049            FDS39   True                   16         48098.0578
#                   FDJ07   True                   20         54528.3542
#                   FDS03   True                   30         74929.7978
#                   FDW39   True                   11         38234.2308
#                   FDM15   True                   12         39679.6826
#                   FDO51   True                   36         83806.9092
#                   FDT51   True                   15         45420.2102
#                   FDP27   True                    8         26336.3848
#                   FDM03   True                   11         34070.3176
#                   FDP51   True                    9         28046.1592
#                   FDV39   True                    5         19571.1910
#                   FDW15   True                    4         11970.4182
# ...

# %%
#Write to an excel :-

# %%
df10.to_excel('Item991.xlsx')

# %%
#Read from the excel file :-

# %%
df=pd.read_excel('C:\\Users\\arpit\\Item991.xlsx')
df
# Out:
#    Outlet_Identifier Item_ID  Mismatched_Weight  Weight  Item_Outlet_Sales  \
# 0             OUT049   FDS39               True      16         48098.0578
# 1             OUT049   FDJ07               True      20         54528.3542
# 2             OUT049   FDS03               True      30         74929.7978
# 3             OUT049   FDW39               True      11         38234.2308
# 4             OUT049   FDM15               True      12         39679.6826
# 5             OUT049   FDO51               True      36         83806.9092
# 6             OUT049   FDT51               True      15         45420.2102
# 7             OUT049   FDP27               True       8         26336.3848
# 8             OUT049   FDM03               True      11         34070.3176
# 9             OUT049   FDP51               True       9         28046.1592
# 10            OUT049   FDV39               True       5         19571.1910
# ...

# %%
#Plot the graphs and show how the Original_Sales column gets calculated on the basis of Item_Sold :-

# %%
df1=df[['Item_ID','Original_Sales','Item_Sold']][:]
df1
# Out:
#    Item_ID  Original_Sales   Item_Sold
# 0    FDS39    36049.863601  253.727190
# 1    FDJ07    35894.978177  313.452196
# 2    FDS03    34838.313621  525.602701
# 3    FDW39    33421.799388  190.941340
# 4    FDM15    31622.887559  207.721977
# 5    FDO51    28540.591714  639.762923
# 6    FDT51    27654.723914  251.282311
# 7    FDP27    23647.935354  125.885322
# 8    FDM03    20723.465781  192.429516
# 9    FDP51    19137.935357  159.599302
# 10   FDV39    17885.498281   90.861929
# 11   FDW15    10521.283189   71.830675
# 12   FDQ51     8684.225353  188.903314
# 13   FDY03     5879.218227   51.973195
# 14   FDU03     4882.388400   27.000000
# 15   FDU51     4776.375600   27.000000
# 16   FDH19     4737.792600   27.000000
# 17   FDN39     4559.803200   27.000000
# 18   FDV51     4530.173400   27.000000
# 19   FDZ39     4134.813873   39.988915
# 20   FDU39     3841.933110   64.835968
# 21   FDK55     3559.701288   39.988915
# 22   FDT27     1881.204236    8.047533
# ...

# %%
fig,ax=plt.subplots(figsize=(8,6))
df1.plot.bar(x='Item_ID',y='Original_Sales',width=0.2,color='orange',label='Item_ID vs Sales & Item_Sold',ax=ax)
df1['Item_Sold'].plot(secondary_y=True,ax=ax,color='b')
ax.set_xticklabels(df1['Item_ID'],rotation=90)
plt.title('Item_ID vs Sales & Item_Sold')
plt.legend()
plt.xlabel('Item_ID')
plt.ylabel('Sales & Item_Sold')
plt.show()

# %%
#Plot the second graph which will show how supermarket owner earns extra_money due to mismatched of Item_Weight.

# %%
df1=df[['Item_ID','Extra_Money','Weight']]
df1
# Out:
#    Item_ID   Extra_Money  Weight
# 0    FDS39  12048.194199      16
# 1    FDJ07  18633.376023      20
# 2    FDS03  40091.484179      30
# 3    FDW39   4812.431412      11
# 4    FDM15   8056.795041      12
# 5    FDO51  55266.317486      36
# 6    FDT51  17765.486286      15
# 7    FDP27   2688.449446       8
# 8    FDM03  13346.851819      11
# 9    FDP51   8908.223843       9
# 10   FDV39   1685.692719       5
# 11   FDW15   1449.135011       4
# 12   FDQ51  13739.252847      10
# 13   FDY03   2399.338973       3
# 14   FDU03     43.200000       1
# 15   FDU51    149.212800       1
# 16   FDH19    187.795800       1
# 17   FDN39    365.785200       1
# 18   FDV51    395.415000       1
# 19   FDZ39   2314.124927       2
# 20   FDU39   4637.695690       3
# 21   FDK55   2889.237512       2
# 22   FDT27     14.994164       1
# 23   FDO03     54.639531       1

# %%
fig,ax=plt.subplots(figsize=(8,6))
df1.plot.bar(x='Item_ID',y='Extra_Money',width=0.2,color='violet',label='Item_ID vs Extra_Money & Weight',ax=ax)
df1['Weight'].plot(secondary_y=True,ax=ax,color='b')
ax.set_xticklabels(df1['Item_ID'],rotation=90)
plt.title('Item_ID vs Extra_Money & Weight')
plt.legend()
plt.xlabel('Item_ID')
plt.ylabel('Extra_Money & Weight')
plt.show()

# %%
#Now let's see the Overall Sales for some other products :-

# %% [markdown]
# #### Breakfast :-

# %%
df5=df4[(df4['Outlet_Identifier']=='OUT049')&(df4['Item_Type_x']=='Breakfast')&(df4['Item_Type_y']=='Breakfast')]
df5
# Out:
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2871               FDP49        9.000          Regular         0.069196
# 2888               FDP49        9.000          Regular         0.069196
# 32648              FDL25        6.920          Regular         0.131128
# 245291             FDN01        8.895          Low Fat         0.072511
# 245308             FDN01        8.895          Low Fat         0.072511
# 263908             FDO13        7.865          Low Fat         0.061155
# 296454             FDO01       21.100          Regular         0.020751
# 296618             FDO01       21.100          Regular         0.020751
# 296751             FDO01       21.100          Regular         0.020751
# 296768             FDO01       21.100          Regular         0.020751
# 296835             FDO01       21.100          Regular         0.020751
# 296847             FDO01       21.100          Regular         0.020751
# ...

# %%
#Calculate Total_Item_Sold :-

# %%
df5['Item_Sold']=df5['Item_Outlet_Sales']/df5['Item_MRP']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2871               FDP49        9.000          Regular         0.069196
# 2888               FDP49        9.000          Regular         0.069196
# 32648              FDL25        6.920          Regular         0.131128
# 245291             FDN01        8.895          Low Fat         0.072511
# 245308             FDN01        8.895          Low Fat         0.072511
# 263908             FDO13        7.865          Low Fat         0.061155
# ...

# %%
#Calculate Original_MRP :-

# %%
df5['Original_Sales']=df5['Item_Sold']*df5['Original_MRP']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2871               FDP49        9.000          Regular         0.069196
# 2888               FDP49        9.000          Regular         0.069196
# 32648              FDL25        6.920          Regular         0.131128
# 245291             FDN01        8.895          Low Fat         0.072511
# 245308             FDN01        8.895          Low Fat         0.072511
# 263908             FDO13        7.865          Low Fat         0.061155
# ...

# %%
#Compare Item_Outlet_Sales and Original_Sales :-

# %%
df5['Greater_Sales']=df5['Item_Outlet_Sales']>df5['Original_Sales']
df5
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 2871               FDP49        9.000          Regular         0.069196
# 2888               FDP49        9.000          Regular         0.069196
# 32648              FDL25        6.920          Regular         0.131128
# 245291             FDN01        8.895          Low Fat         0.072511
# 245308             FDN01        8.895          Low Fat         0.072511
# 263908             FDO13        7.865          Low Fat         0.061155
# ...

# %%
#Now the see the count of unique values in the Greater_Sales column :-

# %%
df5['Greater_Sales'].value_counts()
# Out:
# False    21
# True     15
# Name: Greater_Sales, dtype: int64

# %%
#Subset on the basis of Greater_Sales column :-

# %%
df6=df5[df5['Greater_Sales']==True]
df6.reset_index(drop=True)
# Out:
#    Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDN01        8.895          Low Fat         0.072511
# 1              FDN01        8.895          Low Fat         0.072511
# 2              FDO13        7.865          Low Fat         0.061155
# 3              FDO01       21.100          Regular         0.020751
# 4              FDR37       16.500          Regular         0.066353
# 5              FDR37       16.500          Regular         0.066353
# 6              FDR37       16.500          Regular         0.066353
# 7              FDR37       16.500          Regular         0.066353
# 8              FDO37        8.060          Low Fat         0.021410
# 9              FDO37        8.060          Low Fat         0.021410
# 10             FDK25       11.600          Regular         0.157076
# 11             FDK25       11.600          Regular         0.157076
# 12             FDL13       13.850          Regular         0.056406
# ...

# %%
#Calculate Extra_Sales :-

# %%
df6['Extra_Sales']=df6['Item_Outlet_Sales']-df6['Original_Sales']
df6
# Out:
# C:\Users\arpit\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Item_Identifier_x  Item_Weight Item_Fat_Content  Item_Visibility  \
# 245291             FDN01        8.895          Low Fat         0.072511
# 245308             FDN01        8.895          Low Fat         0.072511
# 263908             FDO13        7.865          Low Fat         0.061155
# 296751             FDO01       21.100          Regular         0.020751
# 397058             FDR37       16.500          Regular         0.066353
# 397191             FDR37       16.500          Regular         0.066353
# ...

# %%
#Apply groupby :-

# %%
df7=df6.groupby(['Outlet_Identifier','Item_Identifier_y','Mismatched_Weight']).agg({'Mismatched_Weight':'count','Item_Outlet_Sales':'sum','Original_Sales':'sum','Extra_Sales':'sum','Item_Sold':'sum'})
df7
# Out:
#                                                        Mismatched_Weight  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM01             True                               6
#                   FDM13             True                               6
#                   FDM25             True                               2
#                   FDP37             True                               1
#
#                                                        Item_Outlet_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM01             True                      23823.6556
#                   FDM13             True                      23047.3328
#                   FDM25             True                       7225.2616
#                   FDP37             True                       4195.8716
#
#                                                        Original_Sales  \
# ...

# %%
#Rename the column :-

# %%
df7.rename({'Mismatched_Weight':'Weight'},axis=1,inplace=True)
df7
# Out:
#                                                        Weight  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM01             True                    6
#                   FDM13             True                    6
#                   FDM25             True                    2
#                   FDP37             True                    1
#
#                                                        Item_Outlet_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM01             True                      23823.6556
#                   FDM13             True                      23047.3328
#                   FDM25             True                       7225.2616
#                   FDP37             True                       4195.8716
#
#                                                        Original_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# ...

# %%
#Assign to a new variable :-

# %%
df8=df7
df8
# Out:
#                                                        Weight  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM01             True                    6
#                   FDM13             True                    6
#                   FDM25             True                    2
#                   FDP37             True                    1
#
#                                                        Item_Outlet_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM01             True                      23823.6556
#                   FDM13             True                      23047.3328
#                   FDM25             True                       7225.2616
#                   FDP37             True                       4195.8716
#
#                                                        Original_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# ...

# %%
#Sort the column :-

# %%
df9=df8.sort_values(by='Original_Sales',ascending=False)
df9
# Out:
#                                                        Weight  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM13             True                    6
#                   FDM01             True                    6
#                   FDM25             True                    2
#                   FDP37             True                    1
#
#                                                        Item_Outlet_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# OUT049            FDM13             True                      23047.3328
#                   FDM01             True                      23823.6556
#                   FDM25             True                       7225.2616
#                   FDP37             True                       4195.8716
#
#                                                        Original_Sales  \
# Outlet_Identifier Item_Identifier_y Mismatched_Weight
# ...

# %%
#Write to an excel file :-

# %%
df9.to_excel('Item009.xlsx')

# %%
#Read from the excel file :-

# %%
df=pd.read_excel('C:\\Users\\arpit\\Item009.xlsx')
df
# Out:
#   Outlet_Identifier Item_Identifier_y  Mismatched_Weight  Weight  \
# 0            OUT049             FDM13               True       6
# 1            OUT049             FDM01               True       6
# 2            OUT049             FDM25               True       2
# 3            OUT049             FDP37               True       1
#
#    Item_Outlet_Sales  Original_Sales   Extra_Sales   Item_Sold
# 0         23047.3328    15748.356327   7298.976473  118.531147
# 1         23823.6556    12973.967613  10849.687987  126.534309
# 2          7225.2616     6384.826461    840.435139   36.242169
# 3          4195.8716     3005.153784   1190.717816   23.152293

# %%
#Rename the columns :-

# %%
df.rename({'Item_Identifier_y':'Item_ID'},axis=1,inplace=True)
df
# Out:
#   Outlet_Identifier Item_ID  Mismatched_Weight  Weight  Item_Outlet_Sales  \
# 0            OUT049   FDM13               True       6         23047.3328
# 1            OUT049   FDM01               True       6         23823.6556
# 2            OUT049   FDM25               True       2          7225.2616
# 3            OUT049   FDP37               True       1          4195.8716
#
#    Original_Sales   Extra_Sales   Item_Sold
# 0    15748.356327   7298.976473  118.531147
# 1    12973.967613  10849.687987  126.534309
# 2     6384.826461    840.435139   36.242169
# 3     3005.153784   1190.717816   23.152293

# %%
#Assign to a new variable :-

# %%
df1=df[['Item_ID','Original_Sales','Item_Sold']]
df1
# Out:
#   Item_ID  Original_Sales   Item_Sold
# 0   FDM13    15748.356327  118.531147
# 1   FDM01    12973.967613  126.534309
# 2   FDM25     6384.826461   36.242169
# 3   FDP37     3005.153784   23.152293

# %%
#Plot graph and show how the Original_Sales is been calculated on the basis of Item_Sold :-

# %%
fig,ax=plt.subplots(figsize=(8,6))
df1.plot.bar(x='Item_ID',y='Original_Sales',width=0.2,color='lightgreen',label='Item_ID vs Sales & Item_Sold',ax=ax)
df1['Item_Sold'].plot(secondary_y=True,ax=ax,color='b')
ax.set_xticklabels(df1['Item_ID'],rotation=90)
plt.title('Item_ID vs Sales & Item_Sold')
plt.legend()
plt.xlabel('Item_ID')
plt.ylabel('Sales & Item_Sold')
plt.show()

# %%
df1=df[['Item_ID','Extra_Sales','Weight']]
df1
# Out:
#   Item_ID   Extra_Sales  Weight
# 0   FDM13   7298.976473       6
# 1   FDM01  10849.687987       6
# 2   FDM25    840.435139       2
# 3   FDP37   1190.717816       1

# %%
#Plot the graph and show how the supermarket owner earns the Extra_Money on the basis of mismatched of Item_Weight :-

# %%
fig,ax=plt.subplots(figsize=(8,6))
df1.plot.bar(x='Item_ID',y='Extra_Sales',width=0.2,color='cyan',label='Item_ID vs Extra_Sales & Weight',ax=ax)
df1['Weight'].plot(secondary_y=True,ax=ax,color='b')
ax.set_xticklabels(df1['Item_ID'],rotation=90)
plt.title('Item_ID vs Extra_Sales & Weight')
plt.legend()
plt.xlabel('Item_ID')
plt.ylabel('Extra_Sales & Weight')
plt.show()
